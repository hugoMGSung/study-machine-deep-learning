# %%
# !nvidia-smi
# Out:
# Sat Jan 27 18:03:18 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 536.67                 Driver Version: 536.67       CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                     TCC/WDDM  | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce GTX 1650 ...  WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   53C    P8               4W /  40W |    285MiB /  4096MiB |     31%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      4816    C+G   ...t.LockApp_cw5n1h2txyewy\LockApp.exe    N/A      |
# |    0   N/A  N/A      8080    C+G   ...ogram Files\Unity Hub\Unity Hub.exe    N/A      |
# |    0   N/A  N/A     13740    C+G   ...ystem32\LockScreenContentServer.exe    N/A      |
# |    0   N/A  N/A     15284    C+G   ...GeForce Experience\NVIDIA Share.exe    N/A      |
# |    0   N/A  N/A     15512    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe    N/A      |
# |    0   N/A  N/A     17464    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     22588    C+G   ...al\Discord\app-1.0.9030\Discord.exe    N/A      |
# |    0   N/A  N/A     30944      C   ...V\LANGS\Python\Python311\python.exe    N/A      |
# |    0   N/A  N/A     37776    C+G   ...ere Pro 2022\Adobe Premiere Pro.exe    N/A      |
# |    0   N/A  N/A     40012    C+G   ...022\CEPHtmlEngine\CEPHtmlEngine.exe    N/A      |
# |    0   N/A  N/A     42196    C+G   ...e\Application\3.24.223.21\whale.exe    N/A      |
# |    0   N/A  N/A     43800    C+G   ...icrosoft\Microsoft VS Code\Code.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %%
import os

HOME = os.getcwd()
print(HOME)
# Out:
# d:\01_Programming\100_HugoBank\Mine\hungout-with-yolo\Yolov8

# %% [markdown]
# #### Install YOLOv8

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.1.6-py3-none-any.whl.metadata (40 kB)
#      ---------------------------------------- 0.0/40.2 kB ? eta -:--:--
#      ---------------------------------------- 40.2/40.2 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: numpy>=1.22.2 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (1.23.5)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (4.7.0.72)
# Requirement already satisfied: pillow>=7.1.2 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (9.5.0)
# Collecting pyyaml>=5.3.1 (from ultralytics)
#   Downloading PyYAML-6.0.1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: requests>=2.23.0 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (2.28.2)
# Requirement already satisfied: scipy>=1.4.1 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.8.0 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (2.1.2+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (0.16.2+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (4.65.0)
# Requirement already satisfied: psutil in c:\users\perso\appdata\roaming\python\python311\site-packages (from ultralytics) (5.9.4)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting thop>=0.1.1 (from ultralytics)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Requirement already satisfied: pandas>=1.1.4 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (1.5.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\dev\langs\python\python311\lib\site-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\langs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\dev\langs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\langs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.39.4)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\dev\langs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\perso\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\langs\python\python311\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\perso\appdata\roaming\python\python311\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\dev\langs\python\python311\lib\site-packages (from pandas>=1.1.4->ultralytics) (2022.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\dev\langs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\dev\langs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\dev\langs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\dev\langs\python\python311\lib\site-packages (from requests>=2.23.0->ultralytics) (2022.12.7)
# Requirement already satisfied: filelock in c:\dev\langs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.12.2)
# Requirement already satisfied: typing-extensions in c:\dev\langs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (4.5.0)
# Requirement already satisfied: sympy in c:\dev\langs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\dev\langs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.0)
# Requirement already satisfied: jinja2 in c:\dev\langs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.1)
# Requirement already satisfied: fsspec in c:\dev\langs\python\python311\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.4.0)
# Requirement already satisfied: colorama in c:\dev\langs\python\python311\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\perso\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\dev\langs\python\python311\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\dev\langs\python\python311\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Downloading ultralytics-8.1.6-py3-none-any.whl (705 kB)
#    ---------------------------------------- 0.0/705.0 kB ? eta -:--:--
#    --------------------------------------  696.3/705.0 kB 14.6 MB/s eta 0:00:01
#    --------------------------------------- 705.0/705.0 kB 11.2 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp311-cp311-win_amd64.whl (144 kB)
#    ---------------------------------------- 0.0/144.7 kB ? eta -:--:--
#    ---------------------------------------- 144.7/144.7 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: py-cpuinfo, pyyaml, thop, ultralytics
# Successfully installed py-cpuinfo-9.0.0 pyyaml-6.0.1 thop-0.1.1.post2209072238 ultralytics-8.1.6

# %%
# !pip install roboflow
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.17-py3-none-any.whl.metadata (9.3 kB)
# Collecting certifi==2023.7.22 (from roboflow)
#   Downloading certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#      -------------------------------------  174.1/178.7 kB 5.3 MB/s eta 0:00:01
#      -------------------------------------- 178.7/178.7 kB 3.6 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Requirement already satisfied: idna==2.10 in c:\dev\langs\python\python311\lib\site-packages (from roboflow) (2.10)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\dev\langs\python\python311\lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in c:\dev\langs\python\python311\lib\site-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\dev\langs\python\python311\lib\site-packages (from roboflow) (1.23.5)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\dev\langs\python\python311\lib\site-packages (from roboflow) (9.5.0)
# Requirement already satisfied: python-dateutil in c:\users\perso\appdata\roaming\python\python311\site-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in c:\dev\langs\python\python311\lib\site-packages (from roboflow) (2.28.2)
# Requirement already satisfied: six in c:\users\perso\appdata\roaming\python\python311\site-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.18.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: urllib3>=1.26.6 in c:\dev\langs\python\python311\lib\site-packages (from roboflow) (1.26.14)
# Requirement already satisfied: tqdm>=4.41.0 in c:\dev\langs\python\python311\lib\site-packages (from roboflow) (4.65.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\dev\langs\python\python311\lib\site-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#      ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: colorama in c:\dev\langs\python\python311\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\dev\langs\python\python311\lib\site-packages (from matplotlib->roboflow) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\dev\langs\python\python311\lib\site-packages (from matplotlib->roboflow) (4.39.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\perso\appdata\roaming\python\python311\site-packages (from matplotlib->roboflow) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\dev\langs\python\python311\lib\site-packages (from matplotlib->roboflow) (3.0.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\dev\langs\python\python311\lib\site-packages (from requests->roboflow) (3.0.1)
# Collecting defusedxml<0.8.0,>=0.7.1 (from supervision->roboflow)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: scipy<2.0.0,>=1.10.0 in c:\dev\langs\python\python311\lib\site-packages (from supervision->roboflow) (1.10.1)
# Downloading roboflow-1.1.17-py3-none-any.whl (70 kB)
#    ---------------------------------------- 0.0/70.0 kB ? eta -:--:--
#    ---------------------------------------- 70.0/70.0 kB 1.9 MB/s eta 0:00:00
# Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#    ---------------------------------------- 0.0/158.3 kB ? eta -:--:--
#    ---------------------------------------- 158.3/158.3 kB 4.8 MB/s eta 0:00:00
# Downloading opencv_python_headless-4.8.0.74-cp37-abi3-win_amd64.whl (38.0 MB)
#    ---------------------------------------- 0.0/38.0 MB ? eta -:--:--
#    - -------------------------------------- 1.2/38.0 MB 24.8 MB/s eta 0:00:02
#    -- ------------------------------------- 2.3/38.0 MB 24.3 MB/s eta 0:00:02
#    --- ------------------------------------ 3.6/38.0 MB 25.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 4.7/38.0 MB 27.1 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.6/38.0 MB 23.7 MB/s eta 0:00:02
#    ------- -------------------------------- 7.1/38.0 MB 25.3 MB/s eta 0:00:02
#    --------- ------------------------------ 8.8/38.0 MB 26.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 10.9/38.0 MB 29.7 MB/s eta 0:00:01
#    ------------- -------------------------- 12.8/38.0 MB 31.2 MB/s eta 0:00:01
#    --------------- ------------------------ 14.8/38.0 MB 34.4 MB/s eta 0:00:01
#    ------------------ --------------------- 17.1/38.0 MB 43.7 MB/s eta 0:00:01
#    -------------------- ------------------- 19.5/38.0 MB 43.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 21.7/38.0 MB 46.9 MB/s eta 0:00:01
#    ------------------------- -------------- 23.8/38.0 MB 50.4 MB/s eta 0:00:01
#    --------------------------- ------------ 26.0/38.0 MB 50.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.1/38.0 MB 50.4 MB/s eta 0:00:01
#    ------------------------------- -------- 30.2/38.0 MB 46.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 33.2/38.0 MB 54.7 MB/s eta 0:00:01
#    ------------------------------------- -- 35.6/38.0 MB 54.7 MB/s eta 0:00:01
#    ---------------------------------------  37.9/38.0 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------  37.9/38.0 MB 54.4 MB/s eta 0:00:01
#    ---------------------------------------- 38.0/38.0 MB 40.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading supervision-0.18.0-py3-none-any.whl (86 kB)
#    ---------------------------------------- 0.0/86.7 kB ? eta -:--:--
#    ------------------------------------- -- 81.9/86.7 kB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 81.9/86.7 kB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 81.9/86.7 kB 4.5 MB/s eta 0:00:01
#    ------------------------------------- -- 81.9/86.7 kB 4.5 MB/s eta 0:00:01
#    ---------------------------------------- 86.7/86.7 kB 406.6 kB/s eta 0:00:00
# Installing collected packages: python-magic, python-dotenv, opencv-python-headless, defusedxml, cycler, chardet, certifi, supervision, requests-toolbelt, roboflow
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\DEV\\LANGS\\Python\\Python311\\Lib\\site-packages\\cv2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.

# %%
from IPython import display

# %%
display.clear_output()

# %%
# !yolo mode=checks
# Out:
# WARNING ⚠️ Ultralytics settings reset to default values. This may be due to a possible problem with your settings or a recent ultralytics package update.
# View settings with 'yolo settings' or at 'C:\Users\perso\AppData\Roaming\Ultralytics\settings.yaml'
# Update settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'.
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\DEV\LANGS\Python\Python311\Scripts\yolo.exe\__main__.py", line 7, in <module>
#   File "C:\DEV\LANGS\Python\Python311\Lib\site-packages\ultralytics\cfg\__init__.py", line 509, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from 'C:\\DEV\\LANGS\\Python\\Python311\\Lib\\site-packages\\ultralytics\\utils\\checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose', 'obb')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
#                     See all ARGS at https://docs.ultralytics.com/usage/cfg or with 'yolo cfg'
#
#     1. Train a detection model for 10 epochs with an initial learning_rate of 0.01
#         yolo train data=coco128.yaml model=yolov8n.pt epochs=10 lr0=0.01
#
#     2. Predict a YouTube video using a pretrained segmentation model at image size 320:
#         yolo predict model=yolov8n-seg.pt source='https://youtu.be/LNwODJXcvt4' imgsz=320
#
#     3. Val a pretrained detection model at batch-size 1 and image size 640:
#         yolo val model=yolov8n.pt data=coco128.yaml batch=1 imgsz=640
#
#     4. Export a YOLOv8n classification model to ONNX format at image size 224 by 128 (no TASK required)
#         yolo export model=yolov8n-cls.pt format=onnx imgsz=224,128
#
#     6. Explore your datasets using semantic search and SQL with a simple GUI powered by Ultralytics Explorer API
#         yolo explorer
#
#     5. Run special commands:
#         yolo help
#         yolo checks
#         yolo version
#         yolo settings
#         yolo copy-cfg
#         yolo cfg
#
#     Docs: https://docs.ultralytics.com
#     Community: https://community.ultralytics.com
#     GitHub: https://github.com/ultralytics/ultralytics

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
# %cd {HOME}

# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# d:\01_Programming\100_HugoBank\Mine\hungout-with-yolo\Yolov8
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# Ultralytics YOLOv8.1.6 🚀 Python-3.11.4 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 with Max-Q Design, 4096MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# image 1/1 d:\01_Programming\100_HugoBank\Mine\hungout-with-yolo\Yolov8\dog.jpeg: 640x384 1 person, 1 car, 1 dog, 73.9ms
# Speed: 9.5ms preprocess, 73.9ms inference, 19.7ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs\detect\predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
#   0%|          | 0.00/6.23M [00:00<?, ?B/s]
#   4%|▍         | 248k/6.23M [00:00<00:02, 2.43MB/s]
#  23%|██▎       | 1.46M/6.23M [00:00<00:00, 8.25MB/s]
#  70%|██████▉   | 4.34M/6.23M [00:00<00:00, 18.0MB/s]
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 17.2MB/s]
#
#   0%|          | 0.00/104k [00:00<?, ?B/s]
# 100%|██████████| 104k/104k [00:00<00:00, 2.50MB/s]

# %%
Image(filename='runs/detect/predict/dog.jpeg', width=300)

# %%
print(HOME)
# Out:
# d:\01_Programming\100_HugoBank\Mine\hungout-with-yolo\Yolov8

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model=yolov8x-seg.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# d:\01_Programming\100_HugoBank\Mine\hungout-with-yolo\Yolov8
# Ultralytics YOLOv8.1.6 🚀 Python-3.11.4 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 with Max-Q Design, 4096MiB)
# YOLOv8x-seg summary (fused): 295 layers, 71797696 parameters, 0 gradients, 344.1 GFLOPs
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 d:\01_Programming\100_HugoBank\Mine\hungout-with-yolo\Yolov8\dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 99.5ms
# Speed: 6.6ms preprocess, 99.5ms inference, 19.0ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs\segment\predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='runs/segment/predict/dog.jpeg', width=300)

# %%
# %cd {HOME}
# !yolo task=segment mode=predict model=yolov8s-seg.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# d:\01_Programming\100_HugoBank\Mine\hungout-with-yolo\Yolov8
# Ultralytics YOLOv8.1.6 🚀 Python-3.11.4 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1650 with Max-Q Design, 4096MiB)
# YOLOv8s-seg summary (fused): 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
#
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 d:\01_Programming\100_HugoBank\Mine\hungout-with-yolo\Yolov8\dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 1 handbag, 78.8ms
# Speed: 2.5ms preprocess, 78.8ms inference, 3.5ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs\segment\predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
Image(filename='runs/segment/predict2/dog.jpeg', width=300)
