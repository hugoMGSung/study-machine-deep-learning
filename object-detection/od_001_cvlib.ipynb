# %% [markdown]
# ### 가상환경 설정
#
# - cvlib_env 사용
#
# ```shell
# > python -m venv cvlib_env
# ```
#
# - 라이브러리 설치
#
# ```shell
# > pip install opencv-python tensorflow
# > pip install cvlib
# ```

# %%
from IPython.display import Image, display

# %%
file_path = '../images/cats-and-dogs.jpg'
display(Image(filename=file_path))

# %% [markdown]
# ### cvlib
# - 파이썬에서 얼굴, 객체 인식을 위한 사용하기 쉬운 라이브러리. opencv와 tensorflow를 사용하기 때문에 둘다 설치 필요
# - https://www.arunponnusamy.com/cvlib/
# - or https://github.com/arunponnusamy/cvlib

# %%
## Image Object Detection
import cv2
import cvlib as cv

image = cv2.imread('../images/people.jpg')
# apply face detection
faces, confidences = cv.detect_face(image)

# loop through detected faces
for face,conf in zip(faces,confidences):

    (startX,startY) = face[0],face[1]
    (endX,endY) = face[2],face[3]

    # draw rectangle over face
    cv2.rectangle(image, (startX,startY), (endX,endY), (0,255,0), 2)

# display output
# press any key to close window           
cv2.imshow('face_detection', image)
cv2.waitKey()

# save output
cv2.imwrite('./output/face_detection.jpg', image)

# release resources
cv2.destroyAllWindows()

# %%
# webcam Object Detection
import cvlib as cv
import cv2

# open webcam
webcam = cv2.VideoCapture(0)

if not webcam.isOpened():
    print("Could not open webcam")
    exit()
    

# loop through frames
while webcam.isOpened():

    # read frame from webcam 
    status, frame = webcam.read()

    if not status:
        print("Could not read frame")
        exit()

    # apply face detection
    face, confidence = cv.detect_face(frame)

    print(face)
    print(confidence)

    # loop through detected faces
    for idx, f in enumerate(face):
        
        (startX, startY) = f[0], f[1]
        (endX, endY) = f[2], f[3]

        # draw rectangle over face
        cv2.rectangle(frame, (startX,startY), (endX,endY), (0,255,0), 2)

        text = "{:.2f}%".format(confidence[idx] * 100)

        Y = startY - 10 if startY - 10 > 10 else startY + 10

        # write confidence percentage on top of face rectangle
        cv2.putText(frame, text, (startX,Y), cv2.FONT_HERSHEY_SIMPLEX, 0.7,
                    (0,255,0), 2)

    # display output
    cv2.imshow("Real-time face detection", frame)

    # press "Q" to stop
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    
# release resources
webcam.release()
cv2.destroyAllWindows()
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [[np.int64(374), np.int64(84), np.int64(515), np.int64(282)]]
# [np.float32(0.84612834)]
# [[np.int64(373), np.int64(86), np.int64(511), np.int64(282)]]
# [np.float32(0.75265265)]
# [[np.int64(365), np.int64(85), np.int64(511), np.int64(282)]]
# [np.float32(0.99395967)]
# [[np.int64(365), np.int64(86), np.int64(511), np.int64(281)]]
# [np.float32(0.9949812)]
# [[np.int64(363), np.int64(83), np.int64(515), np.int64(282)]]
# [np.float32(0.99958235)]
# [[np.int64(362), np.int64(81), np.int64(516), np.int64(281)]]
# [np.float32(0.9997137)]
# [[np.int64(362), np.int64(78), np.int64(517), np.int64(280)]]
# [np.float32(0.9998903)]
# [[np.int64(361), np.int64(78), np.int64(518), np.int64(280)]]
# [np.float32(0.99991524)]
# [[np.int64(363), np.int64(75), np.int64(518), np.int64(280)]]
# [np.float32(0.9999305)]
# [[np.int64(362), np.int64(76), np.int64(519), np.int64(280)]]
# [np.float32(0.9999367)]
# [[np.int64(362), np.int64(74), np.int64(519), np.int64(282)]]
# [np.float32(0.9999677)]
# [[np.int64(364), np.int64(72), np.int64(519), np.int64(283)]]
# [np.float32(0.9999788)]
# [[np.int64(365), np.int64(74), np.int64(519), np.int64(283)]]
# [np.float32(0.99997807)]
# [[np.int64(365), np.int64(75), np.int64(519), np.int64(282)]]
# [np.float32(0.99995875)]
# [[np.int64(365), np.int64(75), np.int64(519), np.int64(282)]]
# [np.float32(0.999964)]
# [[np.int64(366), np.int64(76), np.int64(519), np.int64(282)]]
# [np.float32(0.99995124)]
# [[np.int64(367), np.int64(76), np.int64(519), np.int64(280)]]
# [np.float32(0.9999294)]
# [[np.int64(367), np.int64(68), np.int64(520), np.int64(276)]]
# [np.float32(0.9999269)]
# [[np.int64(366), np.int64(68), np.int64(519), np.int64(274)]]
# [np.float32(0.9998301)]
# [[np.int64(366), np.int64(67), np.int64(519), np.int64(276)]]
# [np.float32(0.9997888)]
# [[np.int64(367), np.int64(53), np.int64(522), np.int64(302)]]
# [np.float32(0.9464212)]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %% [markdown]
# #### Gender Detection
#
# - 실행문제 : 버전 문제가 있는 듯

# %%
# import necessary packages
import cv2
import cvlib as cv
import numpy as np

img = cv2.imread('../images/man_and_woman.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 얼굴 찾기
faces, confidences = cv.detect_face(img)

for (x, y, x2, y2)in faces:

    # 얼굴 roi 지정
    face_img = img[y:y2, x:x2]

    # 성별 예측하기
    label, confidence = cv.detect_gender(face_img)

    cv2.rectangle(img, (x, y), (x2, y2), (0, 255, 0), 2)

    gender = np.argmax(confidence)
    text = f'{label[gender]}:{confidence[gender]:.1%}'
    cv2.putText(img, text, (x,y-10), cv2.FONT_HERSHEY_PLAIN, 1, (0, 255, 0), 1)

# 영상 출력
cv2.imshow('image', img)

key = cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [INFO] Initializing gender detection model ..
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 18
#      15 face_img = img[y:y2, x:x2]
#      17 # 성별 예측하기
# ---> 18 label, confidence = cv.detect_gender(face_img)
#      20 cv2.rectangle(img, (x, y), (x2, y2), (0, 255, 0), 2)
#      22 gender = np.argmax(confidence)
#
# File d:\01_Programming\100_HugoBank\Mine\study-objectdetection\cvlib_env\lib\site-packages\cvlib\gender_detection.py:51, in detect_gender(face, enable_gpu)
#      48 global initialize, gd
#      50 if initialize:
# ---> 51     gd = GenderDetection()
#      52     initialize = False
#      54 return gd.detect_gender(face, enable_gpu)
#
# File d:\01_Programming\100_HugoBank\Mine\study-objectdetection\cvlib_env\lib\site-packages\cvlib\gender_detection.py:28, in GenderDetection.__init__(self)
#      25 self.mean = (78.4263377603, 87.7689143744, 114.895847746)
#      27 print('[INFO] Initializing gender detection model ..')
# ---> 28 self.net = cv2.dnn.readNetFromCaffe(self.proto, self.model)
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\caffe\caffe_io.cpp:1162: error: (-2:Unspecified error) FAILED: ReadProtoFromTextFile(param_file, param). Failed to parse NetParameter file: C:\Users\perso\.cvlib\pre-trained\gender_deploy.prototxt in function 'cv::dnn::ReadNetParamsFromTextFileOrDie'

# %% [markdown]
# #### Object Detection
#
# - CUDA 문제, GPU가 동작하지 않으면 안되는 듯

# %%
import cvlib as cv
from cvlib.object_detection import draw_bbox
import sys
import cv2

# read input image
image = cv2.imread('../images/cats-and-dogs.jpg')

# apply object detection
bbox, label, conf = cv.detect_common_objects(image)

print(bbox, label, conf)

# draw bounding box over detected objects
out = draw_bbox(image, bbox, label, conf)

# display output
# press any key to close window           
cv2.imshow("object_detection", out)
cv2.waitKey()

# save output
cv2.imwrite("object_detection.jpg", out)

# release resources
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[10], line 10
#       7 image = cv2.imread('../images/cats-and-dogs.jpg')
#       9 # apply object detection
# ---> 10 bbox, label, conf = cv.detect_common_objects(image)
#      12 print(bbox, label, conf)
#      14 # draw bounding box over detected objects
#
# File d:\01_Programming\100_HugoBank\Mine\study-objectdetection\cvlib_env\lib\site-packages\cvlib\object_detection.py:125, in detect_common_objects(image, confidence, nms_thresh, model, enable_gpu)
#     123 if initialize:
#     124     classes = populate_class_labels()
# --> 125     net = cv2.dnn.readNet(weights_file_abs_path, config_file_abs_path)
#     126     initialize = False
#     128 # enables opencv dnn module to use CUDA on Nvidia card instead of cpu
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\dnn\src\darknet\darknet_io.cpp:705: error: (-215:Assertion failed) separator_index < line.size() in function 'cv::dnn::darknet::ReadDarknetFromCfgStream'
